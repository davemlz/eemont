# %% [markdown]
# <a href="https://colab.research.google.com/github/davemlz/eemont/blob/master/tutorials/004-Computing-Spectral-Indices-Landsat-8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Computing Spectral Indices in Landsat 8

# %% [markdown]
# - GitHub Repo: [https://github.com/davemlz/eemont](https://github.com/davemlz/eemont)
# - PyPI link: [https://pypi.org/project/eemont/](https://pypi.org/project/eemont/)
# - Documentation: [https://eemont.readthedocs.io/en/latest/index.html](https://eemont.readthedocs.io/en/latest/index.html)

# %% [markdown]
# ## Let's start!

# %% [markdown]
# If required, please uncomment:

# %%
#!pip install eemont
#!pip install geemap

# %% [markdown]
# Import the required packges.

# %%
import ee, eemont, datetime, geemap

# %% [markdown]
# Authenticate and Initialize Earth Engine and geemap.

# %%
Map = geemap.Map()

# %% [markdown]
# Point of interest.

# %%
point = ee.Geometry.Point([-74.0592,11.3172])

# %% [markdown]
# Get, filter, mask clouds and scale the image collection.

# %%
L8 = (ee.ImageCollection('LANDSAT/LC08/C01/T1_SR')
      .filterBounds(point)
      .sort('CLOUD_COVER')
      .first()
      .maskClouds()
      .scale())

# %% [markdown]
# ## Spectral Indices
#
# Spectral indices can be computed for Sentinel-2 and Landsat Products using the `index()` method.

# %%
L8 = L8.index()

# %% [markdown]
# By default, the NDVI is computed and added as a new band.

# %%
L8.bandNames().getInfo()
# Out:
# ['B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B10',
#  'B11',
#  'sr_aerosol',
#  'pixel_qa',
#  'radsat_qa',
#  'NDVI']

# %% [markdown]
# If required, another index can be computed:

# %%
L8 = L8.index('BAI')

# %% [markdown]
# This new index is now added as another new band.

# %%
L8.bandNames().getInfo()
# Out:
# ['B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B10',
#  'B11',
#  'sr_aerosol',
#  'pixel_qa',
#  'radsat_qa',
#  'NDVI',
#  'BAI']

# %% [markdown]
# Multiple indices can also be computed.

# %%
L8 = L8.index(['EVI','GNDVI','RVI'])

# %% [markdown]
# These indices are now added as new bands:

# %%
L8.bandNames().getInfo()
# Out:
# ['B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B10',
#  'B11',
#  'sr_aerosol',
#  'pixel_qa',
#  'radsat_qa',
#  'NDVI',
#  'BAI',
#  'EVI',
#  'GNDVI',
#  'RVI']

# %% [markdown]
# Group of indices can also be added by the group name. The available options are: vegetation, water, burn, snow or all (compute all spectral indices):

# %%
L8 = L8.index('water') # Computes NDWI and MNDWI

# %% [markdown]
# The computed indices are now added as new bands:

# %%
L8.bandNames().getInfo()
# Out:
# ['B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'B6',
#  'B7',
#  'B10',
#  'B11',
#  'sr_aerosol',
#  'pixel_qa',
#  'radsat_qa',
#  'NDVI',
#  'BAI',
#  'EVI',
#  'GNDVI',
#  'RVI',
#  'MNDWI',
#  'NDWI']

# %% [markdown]
# ## Visualization

# %% [markdown]
# Now, let's plot two of the computed indices: GNDVI and NDWI.

# %% [markdown]
# Let's define the visualization parameters for the GNDVI:

# %%
visParamsGNDVI = {
  'min': 0.0,
  'max': 1.0,
  'palette': [
    'FFFFFF', 'CE7E45', 'DF923D', 'F1B555', 'FCD163', '99B718', '74A901',
    '66A000', '529400', '3E8601', '207401', '056201', '004C00', '023B01',
    '012E01', '011D01', '011301'
  ],
}

# %% [markdown]
# Let's define the visualization parameters for the NDWI:

# %%
visParamsNDWI = {
  'min': 0.0,
  'max': 1.0,
  'palette': ['0000ff', '00ffff', 'ffff00', 'ff0000', 'ffffff'],
}

# %% [markdown]
# Use `geemap` to display results:

# %%
Map.centerObject(point)
Map.addLayer(L8.select('GNDVI'),visParamsGNDVI,'GNDVI')
Map.addLayer(L8.select('NDWI'),visParamsNDWI,'NDWI')
Map.add_colorbar(visParamsGNDVI['palette'], caption = 'GNDVI') 
Map.add_colorbar(visParamsNDWI['palette'], caption = 'NDWI') 
Map.addLayerControl()
Map
# Out:
# <svg height="50" width="500"><line x1="0" y1="0" x2="0" y2="20" style="stroke:#0000ff;stroke-width:3;" /><line x1="1" y1="0" x2="1" y2="20" style="stroke:#0002ff;stroke-width:3;" /><line x1="2" y1="0" x2="2" y2="20" style="stroke:#0004ff;stroke-width:3;" /><line x1="3" y1="0" x2="3" y2="20" style="stroke:#0006ff;stroke-width:3;" /><line x1="4" y1="0" x2="4" y2="20" style="stroke:#0008ff;stroke-width:3;" /><line x1="5" y1="0" x2="5" y2="20" style="stroke:#000aff;stroke-width:3;" /><line x1="6" y1="0" x2="6" y2="20" style="stroke:#000cff;stroke-width:3;" /><line x1="7" y1="0" x2="7" y2="20" style="stroke:#000eff;stroke-width:3;" /><line x1="8" y1="0" x2="8" y2="20" style="stroke:#0010ff;stroke-width:3;" /><line x1="9" y1="0" x2="9" y2="20" style="stroke:#0012ff;stroke-width:3;" /><line x1="10" y1="0" x2="10" y2="20" style="stroke:#0014ff;stroke-width:3;" /><line x1="11" y1="0" x2="11" y2="20" style="stroke:#0016ff;stroke-width:3;" /><line x1="12" y1="0" x2="12" y2="20" style="stroke:#0018ff;stroke-width:3;" /><line x1="13" y1="0" x2="13" y2="20" style="stroke:#001aff;stroke-width:3;" /><line x1="14" y1="0" x2="14" y2="20" style="stroke:#001cff;stroke-width:3;" /><line x1="15" y1="0" x2="15" y2="20" style="stroke:#001eff;stroke-width:3;" /><line x1="16" y1="0" x2="16" y2="20" style="stroke:#0020ff;stroke-width:3;" /><line x1="17" y1="0" x2="17" y2="20" style="stroke:#0022ff;stroke-width:3;" /><line x1="18" y1="0" x2="18" y2="20" style="stroke:#0024ff;stroke-width:3;" /><line x1="19" y1="0" x2="19" y2="20" style="stroke:#0026ff;stroke-width:3;" /><line x1="20" y1="0" x2="20" y2="20" style="stroke:#0029ff;stroke-width:3;" /><line x1="21" y1="0" x2="21" y2="20" style="stroke:#002bff;stroke-width:3;" /><line x1="22" y1="0" x2="22" y2="20" style="stroke:#002dff;stroke-width:3;" /><line x1="23" y1="0" x2="23" y2="20" style="stroke:#002fff;stroke-width:3;" /><line x1="24" y1="0" x2="24" y2="20" style="stroke:#0031ff;stroke-width:3;" /><line x1="25" y1="0" x2="25" y2="20" style="stroke:#0033ff;stroke-width:3;" /><line x1="26" y1="0" x2="26" y2="20" style="stroke:#0035ff;stroke-width:3;" /><line x1="27" y1="0" x2="27" y2="20" style="stroke:#0037ff;stroke-width:3;" /><line x1="28" y1="0" x2="28" y2="20" style="stroke:#0039ff;stroke-width:3;" /><line x1="29" y1="0" x2="29" y2="20" style="stroke:#003bff;stroke-width:3;" /><line x1="30" y1="0" x2="30" y2="20" style="stroke:#003dff;stroke-width:3;" /><line x1="31" y1="0" x2="31" y2="20" style="stroke:#003fff;stroke-width:3;" /><line x1="32" y1="0" x2="32" y2="20" style="stroke:#0041ff;stroke-width:3;" /><line x1="33" y1="0" x2="33" y2="20" style="stroke:#0043ff;stroke-width:3;" /><line x1="34" y1="0" x2="34" y2="20" style="stroke:#0045ff;stroke-width:3;" /><line x1="35" y1="0" x2="35" y2="20" style="stroke:#0047ff;stroke-width:3;" /><line x1="36" y1="0" x2="36" y2="20" style="stroke:#0049ff;stroke-width:3;" /><line x1="37" y1="0" x2="37" y2="20" style="stroke:#004bff;stroke-width:3;" /><line x1="38" y1="0" x2="38" y2="20" style="stroke:#004dff;stroke-width:3;" /><line x1="39" y1="0" x2="39" y2="20" style="stroke:#0050ff;stroke-width:3;" /><line x1="40" y1="0" x2="40" y2="20" style="stroke:#0052ff;stroke-width:3;" /><line x1="41" y1="0" x2="41" y2="20" style="stroke:#0054ff;stroke-width:3;" /><line x1="42" y1="0" x2="42" y2="20" style="stroke:#0056ff;stroke-width:3;" /><line x1="43" y1="0" x2="43" y2="20" style="stroke:#0058ff;stroke-width:3;" /><line x1="44" y1="0" x2="44" y2="20" style="stroke:#005aff;stroke-width:3;" /><line x1="45" y1="0" x2="45" y2="20" style="stroke:#005cff;stroke-width:3;" /><line x1="46" y1="0" x2="46" y2="20" style="stroke:#005eff;stroke-width:3;" /><line x1="47" y1="0" x2="47" y2="20" style="stroke:#0060ff;stroke-width:3;" /><line x1="48" y1="0" x2="48" y2="20" style="stroke:#0062ff;stroke-width:3;" /><line x1="49" y1="0" x2="49" y2="20" style="stroke:#0064ff;stroke-width:3;" /><line x1="50" y1="0" x2="50" y2="20" style="stroke:#0066ff;stroke-width:3;" /><line x1="51" ...
# Map(center=[11.317200000000001, -74.0592], controls=(WidgetControl(options=['position'], widget=HBox(children=…
